# %%
# %matplotlib inline
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt

# %%
from skimage import data
photo_data=misc.imread('D:/Python/wifire/sd-3layers.jpg')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
type(photo_data)
# Out:
# numpy.ndarray

# %%
photo_data.shape
# Out:
# (3725, 4797, 3)

# %%
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %%
photo_data.size
# Out:
# 53606475

# %%
photo_data.min(),photo_data.max()
# Out:
# (0, 255)

# %%
photo_data.mean()
# Out:
# 75.8299354508947

# %%
photo_data[150,250]
# Out:
# array([ 17,  35, 255], dtype=uint8)

# %%
photo_data[150,250,1]
# Out:
# 35

# %%
photo_data[150,250]=0

# %%
photo_data[150,250]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
plt.imshow(photo_data)

# %%
photo_data[200:800,:,1]=0

# %%
plt.imshow(photo_data)

# %%
photo_data[200:800,:,1]=255
plt.imshow(photo_data)

# %%
photo_data[200:800,:]=255
plt.imshow(photo_data)

# %%
photo_data[200:800,:]=0
plt.imshow(photo_data)

# %%
photo_data=misc.imread('D:/Python/wifire/sd-3layers.jpg')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.imshow(photo_data)
photo_data[photo_data<200]=0
plt.imshow(photo_data)

# %%
import random

# %%
a=np.random.rand(1000,1000,3)*1000
a[a>100]=0
plt.imshow(a)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
photo_data=misc.imread('D:/Python/wifire/sd-3layers.jpg')
a=np.arange(len(photo_data))
b=np.arange(len(photo_data))
photo_data[a,b]=255
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.imshow(photo_data)
